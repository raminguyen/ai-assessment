# %%
import json
from pathlib import Path

# Path to the JSON file that stores step2 scoring prompt and rubric text together
RUBRIC_JSON_PATH = "/Users/ramihuunguyen/Documents/PhD/AI-Assessment/Essay/Rubrics/aacu_rubrics.json"

# Load JSON config containing step2 prompt and rubric
with open(RUBRIC_JSON_PATH, "r", encoding="utf-8") as f:
    config = json.load(f)

# Directly use the combined step2 scoring prompt from JSON
p2 = config["step2_scoring_prompt"]

print("Generated p2 from JSON:\n")
print(p2[:1000])  # preview first 800 chars
# Out:
# Generated p2 from JSON:
#
# ...

# %%
import pkgutil, importlib, inspect, browser_use

for loader, module_name, ispkg in pkgutil.walk_packages(browser_use.__path__, browser_use.__name__ + "."):
    try:
        mod = importlib.import_module(module_name)
        for name, obj in vars(mod).items():
            if inspect.isclass(obj) and hasattr(obj, "DEFAULT_TIMEOUT"):
                print(f"{module_name}.{name} DEFAULT_TIMEOUT =", getattr(obj, "DEFAULT_TIMEOUT"))
    except Exception:
        pass
# Out:
# ⚠️ CLI addon is not installed. Please install it with: `pip install "browser-use[cli]"` and try again.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/ramihuunguyen/miniconda3/envs/visualization/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# !pip install "browser-use[cli]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 707.8/707.8 kB 18.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [textual]m3/4 [textual]
# ...

# %%
import pkgutil, importlib, inspect, browser_use

for loader, module_name, ispkg in pkgutil.walk_packages(browser_use.__path__, browser_use.__name__ + "."):
    try:
        mod = importlib.import_module(module_name)
        for name, obj in vars(mod).items():
            if inspect.isclass(obj) and "Watchdog" in name:
                if hasattr(obj, "DEFAULT_TIMEOUT"):
                    print(f"{module_name}.{name} DEFAULT_TIMEOUT =", getattr(obj, "DEFAULT_TIMEOUT"))
    except Exception:
        pass
