# %% [markdown]
# ### Load a dataset

# %%
import pandas as pd
import numpy as np
import visualize_scores as visualize
import metrics

# %%
scores = pd.read_csv("scores_all.csv")

# %%
p12_dataset = scores[scores['Prompt'] == "p12"]
p12_dataset.head(10)
# Out:
#     Prompt Assignment EssayType   Writer   Grader  Issues  Evidence  Context  \
# 862    p12         A1  generate  chatgpt   claude     4.0       4.0      3.0
# 863    p12         A1  generate  chatgpt   gemini     4.0       4.0      4.0
# 864    p12         A1  generate  chatgpt     grok     4.0       4.0      4.0
# 865    p12         A1  generate   claude  chatgpt     4.0       3.0      3.0
# 866    p12         A1  generate   claude   gemini     4.0       4.0      4.0
# 867    p12         A1  generate   claude     grok     4.0       4.0      4.0
# 868    p12         A1  generate   gemini  chatgpt     4.0       3.0      3.0
# 869    p12         A1  generate   gemini   claude     4.0       4.0      3.0
# 870    p12         A1  generate   gemini     grok     4.0       4.0      4.0
# 871    p12         A1  generate     grok  chatgpt     4.0       3.0      3.0
#
#      Position  Conclusions  Total  HasZero  Issues_zero  Evidence_zero  \
# 862       4.0          4.0   19.0    False        False          False
# 863       4.0          4.0   20.0    False        False          False
# 864       4.0          4.0   20.0    False        False          False
# 865       3.0          2.0   15.0    False        False          False
# 866       4.0          4.0   20.0    False        False          False
# 867       4.0          3.0   19.0    False        False          False
# 868       4.0          3.0   17.0    False        False          False
# 869       4.0          4.0   19.0    False        False          False
# 870       4.0          4.0   20.0    False        False          False
# 871       3.0          3.0   16.0    False        False          False
#
#      Context_zero  Position_zero  Conclusions_zero
# 862         False          False             False
# 863         False          False             False
# 864         False          False             False
# 865         False          False             False
# 866         False          False             False
# 867         False          False             False
# 868         False          False             False
# 869         False          False             False
# 870         False          False             False
# 871         False          False             False

# %% [markdown]
# ### Grader Bias in Cross-Model Evaluation

# %%
writers = ['chatgpt', 'claude', 'gemini', 'grok']
dimensions = ['Issues', 'Evidence', 'Context', 'Position', 'Conclusions']

# %%
for p in p12_dataset['Prompt'].unique():
    subset = p12_dataset[p12_dataset['Prompt'] == p]
    print ("prompt", p)
    print(subset.groupby(['Assignment', 'EssayType']).size().to_string())
# Out:
# prompt p12
# Assignment  EssayType
# A1          generate     12
#             tune         12
# A2          generate     12
#             tune         12
# A3          generate     12
#             tune         12

# %%
stats_df = metrics.compute_cross_grading_scores(p12_dataset, writers, dimensions, grader=None)
stats_df.tail(10)
len(stats_df)

#group by essaytype and writer and grader and dimension
# 2 essays x 2 writers x 4 graders x 5 dimensions = 160 rows
# Out:
# 160

# %%
grader_df = metrics.compute_cross_grading_scores(p12_dataset, writers, dimensions, grader="claude")

grader_df.head(20)
# Out:
#    EssayType   Writer  Grader    Dimension  N    Mean     Std  Bar_bottom  \
# 0   generate  chatgpt  claude       Issues  3  4.0000  0.0000      4.0000
# 1   generate  chatgpt  claude     Evidence  3  4.0000  0.0000      4.0000
# 2   generate  chatgpt  claude      Context  3  3.3333  0.5774      2.7560
# 3   generate  chatgpt  claude     Position  3  4.0000  0.0000      4.0000
# 4   generate  chatgpt  claude  Conclusions  3  4.0000  0.0000      4.0000
# 5   generate   claude  claude       Issues  0     NaN  0.0000         NaN
# 6   generate   claude  claude     Evidence  0     NaN  0.0000         NaN
# 7   generate   claude  claude      Context  0     NaN  0.0000         NaN
# 8   generate   claude  claude     Position  0     NaN  0.0000         NaN
# 9   generate   claude  claude  Conclusions  0     NaN  0.0000         NaN
# 10  generate   gemini  claude       Issues  3  4.0000  0.0000      4.0000
# 11  generate   gemini  claude     Evidence  3  3.6667  0.5774      3.0893
# 12  generate   gemini  claude      Context  3  3.3333  0.5774      2.7560
# 13  generate   gemini  claude     Position  3  4.0000  0.0000      4.0000
# 14  generate   gemini  claude  Conclusions  3  3.3333  0.5774      2.7560
# 15  generate     grok  claude       Issues  3  4.0000  0.0000      4.0000
# 16  generate     grok  claude     Evidence  3  4.0000  0.0000      4.0000
# 17  generate     grok  claude      Context  3  3.0000  0.0000      3.0000
# 18  generate     grok  claude     Position  3  3.6667  0.5774      3.0893
# 19  generate     grok  claude  Conclusions  3  3.3333  0.5774      2.7560
#
#     Bar_top           Values
# 0    4.0000  [4.0, 4.0, 4.0]
# 1    4.0000  [4.0, 4.0, 4.0]
# 2    3.9107  [3.0, 4.0, 3.0]
# 3    4.0000  [4.0, 4.0, 4.0]
# 4    4.0000  [4.0, 4.0, 4.0]
# 5       NaN               []
# 6       NaN               []
# 7       NaN               []
# 8       NaN               []
# 9       NaN               []
# 10   4.0000  [4.0, 4.0, 4.0]
# 11   4.2440  [4.0, 4.0, 3.0]
# 12   3.9107  [3.0, 4.0, 3.0]
# 13   4.0000  [4.0, 4.0, 4.0]
# 14   3.9107  [4.0, 3.0, 3.0]
# 15   4.0000  [4.0, 4.0, 4.0]
# 16   4.0000  [4.0, 4.0, 4.0]
# 17   3.0000  [3.0, 3.0, 3.0]
# 18   4.2440  [4.0, 4.0, 3.0]
# 19   3.9107  [4.0, 3.0, 3.0]

# %%
visualize.cross_grading_scores_by_essaytype(stats_df, writers, dimensions)

# %% [markdown]
# The chart highlights the grader bias models highlight through cross-evaluation.
#
# - ChatGPT as grader is consistently lower.
# - Gemini and Grok are consistently high and tight.
# - Claude sits in between but shows more variance in all dimensions.
#
# Analyze writer by writer:
#
# ChatGPT (writer):
# - In Generate, Claude grading shows large variance in Context.
# - In Tune, everything tightens and rises.
# - Interpretation: tuning stabilizes how others perceive ChatGPT’s structure.
#
# Claude (writer):
# - ChatGPT consistently penalizes Claude-written essays, and ChatGPT grading show variations for all of dimension unless the issue.
# - For tuned essays, ChatGPT grades on evidence dimension at 3, not improving after tuned.
#
# Gemini (writer):
# - Both ChatGPT and Gemini show high grading variation in most dimensions.
#
#
# Grok (writer):
# -  Grok just gives 4.0 to all models no matter who wrote it.

# %% [markdown]
# ### Writer Performance by Assignment

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.colors as mcolors
import numpy as np
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %%
assignment_bias = metrics.compute_grading_bias_by_assignment(p12_dataset, writers, dimensions)

assignment_bias.head(10)

len(assignment_bias)

#group by 2 essay types x 4 writers x 3 assignments x 5 dimensions = 120 rows
# Out:
# 120

# %%
assignment_bias.head(20)

#Issues Caculation Example

#Consensus  = (4 + 3 + 4) / 3 = 3.67 

#Abs_Bias per grader:
  #Claude: |4 - 3.67| = 0.33
  #Gemini: |3 - 3.67| = 0.67  (rounded from 0.666...)
  #Grok:   |4 - 3.67| = 0.33

#Bias vector = [0.67, 0.33, 0.33]  

#Mean_AbsBias = (0.67 + 0.33 + 0.33) / 3 = 0.4444
# Out:
#    Prompt EssayType   Writer Assignment    Dimension  N       AbsBiasValues  \
# 0     p12  generate  chatgpt         A1       Issues  3     [0.0, 0.0, 0.0]
# 1     p12  generate  chatgpt         A1     Evidence  3     [0.0, 0.0, 0.0]
# 2     p12  generate  chatgpt         A1      Context  3  [0.67, 0.33, 0.33]
# 3     p12  generate  chatgpt         A1     Position  3     [0.0, 0.0, 0.0]
# 4     p12  generate  chatgpt         A1  Conclusions  3     [0.0, 0.0, 0.0]
# 5     p12  generate  chatgpt         A2       Issues  3     [0.0, 0.0, 0.0]
# 6     p12  generate  chatgpt         A2     Evidence  3     [0.0, 0.0, 0.0]
# 7     p12  generate  chatgpt         A2      Context  3     [0.0, 0.0, 0.0]
# 8     p12  generate  chatgpt         A2     Position  3     [0.0, 0.0, 0.0]
# 9     p12  generate  chatgpt         A2  Conclusions  3     [0.0, 0.0, 0.0]
# 10    p12  generate  chatgpt         A3       Issues  3     [0.0, 0.0, 0.0]
# 11    p12  generate  chatgpt         A3     Evidence  3     [0.0, 0.0, 0.0]
# 12    p12  generate  chatgpt         A3      Context  3  [0.67, 0.33, 0.33]
# 13    p12  generate  chatgpt         A3     Position  3     [0.0, 0.0, 0.0]
# 14    p12  generate  chatgpt         A3  Conclusions  3     [0.0, 0.0, 0.0]
# 15    p12  generate   claude         A1       Issues  3     [0.0, 0.0, 0.0]
# 16    p12  generate   claude         A1     Evidence  3  [0.67, 0.33, 0.33]
# 17    p12  generate   claude         A1      Context  3  [0.67, 0.33, 0.33]
# 18    p12  generate   claude         A1     Position  3  [0.67, 0.33, 0.33]
# 19    p12  generate   claude         A1  Conclusions  3     [1.0, 1.0, 0.0]
#
#     Consensus  Mean_AbsBias
# 0        4.00        0.0000
# 1        4.00        0.0000
# 2        3.67        0.4444
# 3        4.00        0.0000
# 4        4.00        0.0000
# 5        4.00        0.0000
# 6        4.00        0.0000
# 7        4.00        0.0000
# 8        4.00        0.0000
# 9        4.00        0.0000
# 10       4.00        0.0000
# 11       4.00        0.0000
# 12       3.67        0.4444
# 13       4.00        0.0000
# 14       4.00        0.0000
# 15       4.00        0.0000
# 16       3.67        0.4444
# 17       3.67        0.4444
# 18       3.67        0.4444
# 19       3.00        0.6667

# %%
visualize.grading_bias_by_assignment(assignment_bias, writers, target_writer=None)

# %% [markdown]
# Generate essays:
#
# - A3 is consistently the largest contributor.
# - A2 is usually the smallest.
#
# Tuned essays:
#
# - Bias magnitude is roughly half (or less) of Generate.
# - No extreme spikes like 0.53.
# - Disagreement is more evenly distributed.

# %%
from scipy import stats

# Retrieve data
conclusions = assignment_bias[assignment_bias['Dimension'] == 'Conclusions']['Mean_AbsBias']
context = assignment_bias[assignment_bias['Dimension'] == 'Context']['Mean_AbsBias']
evidence = assignment_bias[assignment_bias['Dimension'] == 'Evidence']['Mean_AbsBias']
issues = assignment_bias[assignment_bias['Dimension'] == 'Issues']['Mean_AbsBias']
position = assignment_bias[assignment_bias['Dimension'] == 'Position']['Mean_AbsBias']

# %%
# P-value
conclusions_t, conclusions_p = stats.ttest_1samp(conclusions, popmean=0)
context_t, context_p = stats.ttest_1samp(context, popmean=0)
evidence_t, evidence_p = stats.ttest_1samp(evidence, popmean=0)
issues_t, issues_p = stats.ttest_1samp(issues, popmean=0)
position_t, position_p = stats.ttest_1samp(position, popmean=0)

# %%
results = {
    'Conclusions': (conclusions_t, conclusions_p),
    'Context':     (context_t,     context_p),
    'Evidence':    (evidence_t,    evidence_p),
    'Issues':      (issues_t,      issues_p),
    'Position':    (position_t,    position_p)
}

# %%
for dim, (t, p) in sorted(results.items(), key=lambda x: x[1][0]):

    stars = "***" if p < 0.001 else "**" if p < 0.01 else "*" if p < 0.05 else "ns"
    
    print(dim, round(t, 2), round(p, 4), stars)
# Out:
# Context 4.05 0.0005 ***
# Conclusions 6.07 0.0 ***
# Evidence 6.19 0.0 ***
# Issues nan nan ns
# Position 3.71 0.0011 **

# %% [markdown]
# ==> All 5 dimensions show statistically significant grader bias. Evidence is the hardest dimension for 4 AI models to grade on.

# %% [markdown]
# ### Do two specific models grade differently by each dimension from each other?

# %%
dimensions = ['Issues', 'Evidence', 'Context', 'Position', 'Conclusions']
pair_names = ['Claude vs Gemini', 'Claude vs Grok', 'Claude vs ChatGPT',
              'Gemini vs Grok',   'Gemini vs ChatGPT', 'Grok vs ChatGPT']

# %%
rows = []

for dim in dimensions:
    for name, grader_a, grader_b in [
        ('Claude vs Gemini',  'claude',  'gemini'),
        ('Claude vs Grok',    'claude',  'grok'),
        ('Claude vs ChatGPT', 'claude',  'chatgpt'),
        ('Gemini vs Grok',    'gemini',  'grok'),
        ('Gemini vs ChatGPT', 'gemini',  'chatgpt'),
        ('Grok vs ChatGPT',   'grok',    'chatgpt'),
    ]:
        a = p12_dataset[p12_dataset['Grader'] == grader_a][dim].values
        b = p12_dataset[p12_dataset['Grader'] == grader_b][dim].values

        if np.std(a - b) == 0:
            p = 1.0
        else:
            t, p = stats.ttest_rel(a, b)
            p = round(p, 4)

        rows.append({'Pair': name, 'Dimension': dim, 'P_value': p})

# %%
results_df = pd.DataFrame(rows)
results_df
# Out:
#                  Pair    Dimension  P_value
# 0    Claude vs Gemini       Issues   1.0000
# 1      Claude vs Grok       Issues   1.0000
# 2   Claude vs ChatGPT       Issues   1.0000
# 3      Gemini vs Grok       Issues   1.0000
# 4   Gemini vs ChatGPT       Issues   1.0000
# 5     Grok vs ChatGPT       Issues   1.0000
# 6    Claude vs Gemini     Evidence   0.3313
# 7      Claude vs Grok     Evidence   0.1631
# 8   Claude vs ChatGPT     Evidence   0.0000
# 9      Gemini vs Grok     Evidence   0.3313
# 10  Gemini vs ChatGPT     Evidence   0.0000
# 11    Grok vs ChatGPT     Evidence   0.0000
# 12   Claude vs Gemini      Context   0.0096
# 13     Claude vs Grok      Context   0.0096
# 14  Claude vs ChatGPT      Context   0.1631
# 15     Gemini vs Grok      Context   1.0000
# 16  Gemini vs ChatGPT      Context   0.0018
# 17    Grok vs ChatGPT      Context   0.0018
# 18   Claude vs Gemini     Position   0.1631
# 19     Claude vs Grok     Position   0.1631
# 20  Claude vs ChatGPT     Position   0.0293
# 21     Gemini vs Grok     Position   1.0000
# 22  Gemini vs ChatGPT     Position   0.0018
# 23    Grok vs ChatGPT     Position   0.0018
# 24   Claude vs Gemini  Conclusions   0.0827
# 25     Claude vs Grok  Conclusions   0.1872
# 26  Claude vs ChatGPT  Conclusions   0.0007
# 27     Gemini vs Grok  Conclusions   1.0000
# 28  Gemini vs ChatGPT  Conclusions   0.0000
# 29    Grok vs ChatGPT  Conclusions   0.0000

# %%
pval_matrix  = results_df.pivot(index='Pair', columns='Dimension', values='P_value')

pval_matrix
# Out:
# Dimension          Conclusions  Context  Evidence  Issues  Position
# Pair
# Claude vs ChatGPT       0.0007   0.1631    0.0000     1.0    0.0293
# Claude vs Gemini        0.0827   0.0096    0.3313     1.0    0.1631
# Claude vs Grok          0.1872   0.0096    0.1631     1.0    0.1631
# Gemini vs ChatGPT       0.0000   0.0018    0.0000     1.0    0.0018
# Gemini vs Grok          1.0000   1.0000    0.3313     1.0    1.0000
# Grok vs ChatGPT         0.0000   0.0018    0.0000     1.0    0.0018

# %%
fig, ax = plt.subplots(figsize=(11, 6))

# Create binary matrix: 1 = significant, 0 = not
binary_matrix = (pval_matrix.values.astype(float) < 0.05).astype(int)

for i in range(len(pval_matrix.index)):
    for j in range(len(pval_matrix.columns)):
        p = pval_matrix.iloc[i, j]
        color = 'white' if p < 0.05 else 'black'
        ax.text(j, i, f'{p:.3f}', ha='center', va='center', fontsize=10, color=color)

im = ax.imshow(binary_matrix, cmap='Blues', vmin=0, vmax=1)

ax.set_xticks(range(len(pval_matrix.columns)))
ax.set_xticklabels(pval_matrix.columns, fontsize=11)
ax.set_yticks(range(len(pval_matrix.index)))
ax.set_yticklabels(pval_matrix.index, fontsize=10)

ax.set_title('Significant Grader Differences (p < 0.05)', fontsize=14, pad=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# - No pair shows significant difference on Issues.
# - ChatGPT is the primary driver of grader disagreement, showing statistically significant differences from Claude, Gemini, and Grok across Evidence, Conclusions, and Position dimensions.
# - Claude, Gemini, and Grok consistently gave similar scores to each other across all dimensions.
